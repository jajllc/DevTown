# %% [markdown]
# <a href="https://colab.research.google.com/github/jajllc/DevTown/blob/main/DevTown_Excel_Python_Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Libraries
import numpy as np
import pandas as pd

# %%
df=pd.read_excel("/content/sales2.xlsx")
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Slicer List extension is not supported and will be removed
#   warn(msg)

# %%
df.head()
# Out:
#   Order ID                 Date Product     Category Region  Quantity  \
# 0     1001  2026-01-01 00:00:00  Laptop  Electronics  North       2.0
# 1     1002  2026-01-02 00:00:00   Mouse  Electronics  South       5.0
# 2     1003  2026-01-03 00:00:00   Chair    Furniture   East       3.0
# 3     1004  2026-01-04 00:00:00  Laptop  Electronics   West       1.0
# 4     1005  2026-01-05 00:00:00    Desk    Furniture  North       2.0
#
#      Price     Sales
# 0  50000.0  100000.0
# 1    500.0    2500.0
# 2   4000.0   12000.0
# 3  50000.0    6000.0
# 4  10000.0   20000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Order ID  12 non-null     object
#  1   Date      12 non-null     object
#  2   Product   8 non-null      object
#  3   Category  8 non-null      object
#  4   Region    8 non-null      object
#  5   Quantity  8 non-null      float64
#  6   Price     8 non-null      float64
#  7   Sales     9 non-null      float64
# dtypes: float64(3), object(5)
# memory usage: 964.0+ bytes

# %%
df.tail()
# Out:
#        Order ID          Date Product Category Region  Quantity  Price  \
# 8           NaN           NaN     NaN      NaN    NaN       NaN    NaN
# 9    Row Labels  Sum of Sales     NaN      NaN    NaN       NaN    NaN
# 10         East          5000     NaN      NaN    NaN       NaN    NaN
# 11        South          2500     NaN      NaN    NaN       NaN    NaN
# 12  Grand Total          7500     NaN      NaN    NaN       NaN    NaN
#
#        Sales
# 8   211500.0
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN

# %%
df.describe()
# Out:
#         Quantity         Price          Sales
# count   8.000000      8.000000       9.000000
# mean    3.500000  21125.000000   47000.000000
# std     2.976095  24090.232164   69118.105443
# min     1.000000    500.000000    2500.000000
# 25%     1.750000   3125.000000    6000.000000
# 50%     2.500000   7000.000000   16000.000000
# 75%     4.250000  50000.000000   50000.000000
# max    10.000000  50000.000000  211500.000000

# %%
df.shape
# Out:
# (13, 8)

# %%
df.columns
# Out:
# Index(['Order ID', 'Date', 'Product', 'Category', 'Region', 'Quantity',
#        'Price', 'Sales'],
#       dtype='object')

# %% [markdown]
# # Filtering

# %%
df[df['Region']=="North"]
# Out:
#   Order ID                 Date Product     Category Region  Quantity  \
# 0     1001  2026-01-01 00:00:00  Laptop  Electronics  North       2.0
# 4     1005  2026-01-05 00:00:00    Desk    Furniture  North       2.0
# 7     1008  2026-01-08 00:00:00  Laptop  Electronics  North       1.0
#
#      Price     Sales
# 0  50000.0  100000.0
# 4  10000.0   20000.0
# 7  50000.0   50000.0

# %%
# Filter electronic catagory
df[df['Category']=="Electronics"]
# Out:
#   Order ID                 Date Product     Category Region  Quantity  \
# 0     1001  2026-01-01 00:00:00  Laptop  Electronics  North       2.0
# 1     1002  2026-01-02 00:00:00   Mouse  Electronics  South       5.0
# 3     1004  2026-01-04 00:00:00  Laptop  Electronics   West       1.0
# 5     1006  2026-01-06 00:00:00   Mouse  Electronics   East      10.0
# 7     1008  2026-01-08 00:00:00  Laptop  Electronics  North       1.0
#
#      Price     Sales
# 0  50000.0  100000.0
# 1    500.0    2500.0
# 3  50000.0    6000.0
# 5    500.0    5000.0
# 7  50000.0   50000.0

# %%
df.sort_values("Sales", ascending=False)
# Out:
#        Order ID                 Date Product     Category Region  Quantity  \
# 8           NaN                  NaN     NaN          NaN    NaN       NaN
# 0          1001  2026-01-01 00:00:00  Laptop  Electronics  North       2.0
# 7          1008  2026-01-08 00:00:00  Laptop  Electronics  North       1.0
# 4          1005  2026-01-05 00:00:00    Desk    Furniture  North       2.0
# 6          1007  2026-01-07 00:00:00   Chair    Furniture  South       4.0
# 2          1003  2026-01-03 00:00:00   Chair    Furniture   East       3.0
# 3          1004  2026-01-04 00:00:00  Laptop  Electronics   West       1.0
# 5          1006  2026-01-06 00:00:00   Mouse  Electronics   East      10.0
# 1          1002  2026-01-02 00:00:00   Mouse  Electronics  South       5.0
# 9    Row Labels         Sum of Sales     NaN          NaN    NaN       NaN
# 10         East                 5000     NaN          NaN    NaN       NaN
# ...

# %%
# Sort for High Qty at top

# %%
df.sort_values("Quantity", ascending=False)
# Out:
#        Order ID                 Date Product     Category Region  Quantity  \
# 5          1006  2026-01-06 00:00:00   Mouse  Electronics   East      10.0
# 1          1002  2026-01-02 00:00:00   Mouse  Electronics  South       5.0
# 6          1007  2026-01-07 00:00:00   Chair    Furniture  South       4.0
# 2          1003  2026-01-03 00:00:00   Chair    Furniture   East       3.0
# 4          1005  2026-01-05 00:00:00    Desk    Furniture  North       2.0
# 0          1001  2026-01-01 00:00:00  Laptop  Electronics  North       2.0
# 3          1004  2026-01-04 00:00:00  Laptop  Electronics   West       1.0
# 7          1008  2026-01-08 00:00:00  Laptop  Electronics  North       1.0
# 8           NaN                  NaN     NaN          NaN    NaN       NaN
# 9    Row Labels         Sum of Sales     NaN          NaN    NaN       NaN
# 10         East                 5000     NaN          NaN    NaN       NaN
# ...

# %%
#KPI Values
# Total Revenue
df['Sales'].sum()
# Out:
# np.float64(423000.0)

# %%
#Average Sale
df['Sales'].mean()
# Out:
# np.float64(47000.0)

# %%
# Highest Sale
df['Sales'].max()
# Out:
# 211500.0

# %%
#Lowest Sale
df['Sales'].min()
# Out:
# 2500.0

# %%
#Total Orders
df['Order ID'].count()
# Out:
# np.int64(12)
